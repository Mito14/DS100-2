# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("C:\\Users\\migue\\Documents\\Python Scripts\\athletes.xlsx")
pd.set_option('display.max_rows', None)
new_data = data.loc[data['nationality'].str.contains('USA|BRA')]
new_data
# Out:
#               id                                   name nationality     sex  \
# 6      266237702                          Aaron Russell         USA    male
# 13     376068084                       Abbey D'Agostino         USA  female
# 14     162792594                         Abbey Weitzeil         USA  female
# 64     884912136                       Abigail Johnston         USA  female
# 79     236523132                              Adam Imer         BRA    male
# 104    259002430                     Adeline Maria Gray         USA  female
# 106    993710181                      Adenizia da Silva         BRA  female
# 109    930618704                       Adilson da Silva         BRA    male
# 114    787208883                          Adrian Baches         BRA    male
# 128     80367651             Adriana Aparecida da Silva         BRA  female
# 129    593328448                         Adriana Araujo         BRA  female
# ...

# %%
pd.set_option('display.max_rows', None)
new_data = new_data.loc[new_data['sport'].str.contains('aquatics|gymnastics')]
new_data
# Out:
#               id                       name nationality     sex       dob  \
# 14     162792594             Abbey Weitzeil         USA  female   12/3/96
# 64     884912136           Abigail Johnston         USA  female  11/16/89
# 114    787208883              Adrian Baches         BRA    male    4/7/90
# 352    334218519                 Alex Bowen         USA    male    9/4/93
# 362    531765497                 Alex Obert         USA    male  12/18/91
# 364    240862321                Alex Roelse         USA    male   1/10/95
# 394    536913332          Alexander Naddour         USA    male    3/4/91
# 418     71010173          Alexandra Raisman         USA  female   5/25/94
# 514    473463517                 Alisa Kano         USA  female   11/7/94
# 532    846754382             Allan do carmo         BRA    male    8/3/89
# 539    944908522            Allison Schmitt         USA  female    6/7/90
# 588    936271742            Amanda Oliveira         BRA  female    1/6/87
# ...

# %%
new_data['BMI']=np.round(new_data['weight']/new_data['height']**2, 2)
new_data
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_17632\1818375535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['BMI']=np.round(new_data['weight']/new_data['height']**2, 2)
#               id                       name nationality     sex       dob  \
# 14     162792594             Abbey Weitzeil         USA  female   12/3/96
# 64     884912136           Abigail Johnston         USA  female  11/16/89
# 114    787208883              Adrian Baches         BRA    male    4/7/90
# 352    334218519                 Alex Bowen         USA    male    9/4/93
# 362    531765497                 Alex Obert         USA    male  12/18/91
# 364    240862321                Alex Roelse         USA    male   1/10/95
# ...

# %%
new_data['Total number of Medals']=np.round(new_data['gold']+new_data['silver']+new_data['bronze'])
new_data
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_17632\1548956843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Total number of Medals']=np.round(new_data['gold']+new_data['silver']+new_data['bronze'])
#               id                       name nationality     sex       dob  \
# 14     162792594             Abbey Weitzeil         USA  female   12/3/96
# 64     884912136           Abigail Johnston         USA  female  11/16/89
# 114    787208883              Adrian Baches         BRA    male    4/7/90
# 352    334218519                 Alex Bowen         USA    male    9/4/93
# 362    531765497                 Alex Obert         USA    male  12/18/91
# ...

# %%
df1 = new_data.loc[new_data['nationality'].str.contains('USA')]
df1 = (df1.rename(columns={'name':'Name','nationality': 'Country','sex': 'Gender', 'sport': 'Sport'}))
df1 = df1.drop(columns=['dob','height','weight','id','gold','silver','bronze'])
abs_data = df1
abs_data[['Name','Country','Gender','BMI','Sport','Total number of Medals']]
# Out:
#                      Name Country  Gender    BMI       Sport  \
# 14         Abbey Weitzeil     USA  female  21.46    aquatics
# 64       Abigail Johnston     USA  female  22.14    aquatics
# 352            Alex Bowen     USA    male  26.55    aquatics
# 362            Alex Obert     USA    male  27.33    aquatics
# 364           Alex Roelse     USA    male  27.63    aquatics
# 394     Alexander Naddour     USA    male  23.94  gymnastics
# 418     Alexandra Raisman     USA  female  20.83  gymnastics
# 514            Alisa Kano     USA  female  17.69  gymnastics
# 539       Allison Schmitt     USA  female  21.39    aquatics
# 592           Amanda Weir     USA  female  21.79    aquatics
# 612          Amelia Cozad     USA  female  19.68    aquatics
# 913         Anita Alvarez     USA  female  17.44    aquatics
# 1018        Anthony Ervin     USA    male  21.93    aquatics
# 1100         Aria Fischer     USA  female  23.29    aquatics
# ...

# %% [markdown]
# Bairan, Joshua Miguel D.
#
# 2020380009
#
# Discussion: The topic that I chose was about 2016 Olympics in Rio de Janeiro. The file provides data about the athletes who joined the Olympics back in 2016. The first thing that I did was to import numpy and pandas. I used codes and named them new_data, and it only got the data with the nationality USA and BRA because of the code I used; then I got the data that contained the sport aquatics and gymnastics to make the data even smaller. Next, I got their BMI or Body Mass Index using their respective weight and height, I also got their Total number of Medals by adding the gold, silver and bronze ones they got. For the last code, I just cleaned it up and rearranged the data set with the new columns I encoded. Thank you!
